# %%
import pandas as pd

# %%
csv_file = "C:\\Users\\jross\\OneDrive\\Data Analytics\\Projects\\FakeNews\\FakeNewsNet-master\\dataset\\gossipcop_fake.csv"
gossipcop_fake = pd.read_csv(csv_file)
csv_file = "C:\\Users\\jross\\OneDrive\\Data Analytics\\Projects\\FakeNews\\FakeNewsNet-master\\dataset\\gossipcop_real.csv"
gossipcop_real = pd.read_csv(csv_file)
csv_file = "C:\\Users\\jross\\OneDrive\\Data Analytics\\Projects\\FakeNews\\FakeNewsNet-master\\dataset\\politifact_real.csv"
politifact_real = pd.read_csv(csv_file)
csv_file = "C:\\Users\\jross\\OneDrive\\Data Analytics\\Projects\\FakeNews\\FakeNewsNet-master\\dataset\\politifact_fake.csv"
politifact_fake = pd.read_csv(csv_file)

# %%
gossipcop_fake.head(4)
# Out:
#                      id                                           news_url  \
# 0  gossipcop-2493749932  www.dailymail.co.uk/tvshowbiz/article-5874213/...
# 1  gossipcop-4580247171  hollywoodlife.com/2018/05/05/paris-jackson-car...
# 2   gossipcop-941805037  variety.com/2017/biz/news/tax-march-donald-tru...
# 3  gossipcop-2547891536  www.dailymail.co.uk/femail/article-3499192/Do-...
#
#                                                title  \
# 0  Did Miley Cyrus and Liam Hemsworth secretly ge...
# 1  Paris Jackson & Cara Delevingne Enjoy Night Ou...
# 2  Celebrities Join Tax March in Protest of Donal...
# 3  Cindy Crawford's daughter Kaia Gerber wears a ...
#
#                                            tweet_ids
# 0  284329075902926848\t284332744559968256\t284335...
# 1  992895508267130880\t992897935418503169\t992899...
# 2  853359353532829696\t853359576543920128\t853359...
# 3  988821905196158981\t988824206556172288\t988825...

# %%
import nltk
from nltk.tokenize import word_tokenize
import numpy as np

# %%
gossipcop_fake['title'].head(4)
# Out:
# 0    Did Miley Cyrus and Liam Hemsworth secretly ge...
# 1    Paris Jackson & Cara Delevingne Enjoy Night Ou...
# 2    Celebrities Join Tax March in Protest of Donal...
# 3    Cindy Crawford's daughter Kaia Gerber wears a ...
# Name: title, dtype: object

# %%
def series_to_tokens(series):
    np_array = np.array([])
    for title in series:
        np_array = np.append(np_array, word_tokenize(title))
    return np_array

# %%
gossipcop_fake['title'].iloc[0]
# Out:
# 'Did Miley Cyrus and Liam Hemsworth secretly get married?'

# %%
# %timeit
#thing = gossipcop_fake['title'].apply(series_to_tokens)
fake_title_words = series_to_tokens(gossipcop_fake['title'].values)

# %%
import collections

# %%
fake_title_counter = dict(collections.Counter(fake_title_words))

# %%
print(len(fake_title_counter))

def dict_filter(my_dict, low_val=10, high_val=None):
    filtered_dict = dict()
    for (key, value) in my_dict.items():
        if high_val is None:
            if value > low_val:
                filtered_dict[key] = value
        else:
            if value > low_val and value < high_val:
                filtered_dict[key] = value
    return filtered_dict
# Out:
# 9466

# %%
a300_fake_title_counter = dict_filter(fake_title_counter, 300)
print((a300_fake_title_counter))
# Out:
# {'and': 992, '?': 709, '&': 484, ':': 968, '‘': 704, '’': 1580, 'in': 308, 'of': 442, "'s": 748, 'a': 387, 'Jenner': 382, 'With': 457, 'To': 495, 's': 705, 'The': 422, ',': 954, 'Is': 531, 'Justin': 350, "'": 676, 'Jennifer': 477, 'Brad': 411, 'Pitt': 379, '!': 365, 'to': 702, 'on': 325, 'the': 491, 'Her': 311, 'Kardashian': 466}

# %%
a200_300title_counter = dict_filter(fake_title_counter, 200, 301)
print(a200_300title_counter)
# Out:
# {'In': 230, 'with': 266, 'For': 222, 'A': 251, 'On': 218, 'Selena': 241, 'Gomez': 231, 'Bieber': 206, 'Aniston': 279, 'Angelina': 290, 'Jolie': 285, 'She': 205, 'After': 249, 'About': 225, 'for': 273, 'Kim': 288, 'Meghan': 225, 'Markle': 203}

# %%
fake_title_words_2 = series_to_tokens(politifact_fake['title'].values)
true_title_words = series_to_tokens(politifact_real['title'].values)
fake_title_words = np.append(fake_title_words, fake_title_words_2)

# %%
len(fake_title_words)
# Out:
# 73408

# %%
fake_title_counter = dict(collections.Counter(fake_title_words))
a300_fake_title_counter = dict_filter(fake_title_counter, 300)
print((a300_fake_title_counter))
# Out:
# {'and': 1017, '?': 722, '&': 490, ':': 1115, '‘': 747, '’': 1692, 'in': 356, 'of': 478, "'s": 757, 'a': 402, 'Jenner': 382, 'With': 478, 'To': 569, 's': 747, 'The': 470, ',': 1047, 'Is': 557, 'Justin': 350, "'": 690, 'Jennifer': 478, 'Brad': 412, 'Pitt': 380, '!': 409, 'to': 752, 'on': 348, 'the': 522, 'Her': 324, 'Kardashian': 466}

# %%
true_title_words_2 = series_to_tokens(gossipcop_real['title'].values)

# %%
true_title_counter = dict(collections.Counter(true_title_words))

# %%
print(len(fake_title_words))
print(len(true_title_words))
true_title_counter
# Out:
# 73408
# 5596
# {'National': 9,
#  'Federation': 1,
#  'of': 122,
#  'Independent': 1,
#  'Business': 4,
#  'comments': 3,
#  'in': 68,
#  'Fayetteville': 1,
#  'NC': 1,
#  'Romney': 9,
#  'makes': 1,
#  'pitch': 1,
#  ',': 192,
#  'hoping': 1,
#  'to': 74,
#  'close': 1,
#  'deal': 3,
#  ':': 141,
#  'Elections': 2,
#  'The': 42,
#  'Rocky': 1,
#  'Mountain': 1,
#  'News': 30,
#  'Democratic': 15,
#  'Leaders': 1,
#  'Say': 2,
#  'House': 15,
#  'Democrats': 5,
#  'Are': 2,
#  'United': 13,
#  'Against': 4,
#  'GOP': 9,
#  'Default': 1,
#  'Act': 17,
#  'Budget': 8,
#  'the': 128,
#  'States': 13,
#  'Government': 6,
#  'FY': 2,
#  '2008': 8,
#  'Donald': 7,
#  'Trump': 22,
#  'exaggerates': 1,
#  'when': 1,
#  'he': 3,
#  'says': 21,
#  'China': 3,
#  'has': 3,
#  "'total": 1,
#  'control': 1,
#  "'": 40,
#  'over': 3,
#  'North': 1,
#  'Korea': 1,
#  '25th': 2,
#  'Amendment': 3,
#  '子供たちのコト。私のコト。': 1,
#  'Briefing': 4,
#  'by': 38,
#  'White': 6,
#  'Press': 9,
#  'Secretary': 3,
#  'Robert': 2,
#  'Gibbs': 2,
#  '9/10/09': 1,
#  'A': 18,
#  'Solar': 2,
#  'Grand': 1,
#  'Plan': 5,
#  'Scientific': 1,
#  'American': 7,
#  'Covering': 1,
#  'Young': 1,
#  'Adults': 1,
#  'Under': 2,
#  'Affordable': 4,
#  'Care': 13,
#  'Importance': 1,
#  'Outreach': 1,
#  'and': 97,
#  'Medicaid': 2,
#  'Expansion': 1,
#  'Harry': 2,
#  'Reid': 2,
#  'Says': 3,
#  'Should': 2,
#  '``': 17,
#  'Stop': 4,
#  'Crying': 1,
#  "''": 16,
#  'About': 6,
#  'Reconciliation': 1,
#  'Political': 13,
#  'TV': 10,
#  'Ad': 14,
#  'Archive': 4,
#  '»': 4,
#  'PolAd': 4,
#  'Bureau': 4,
#  'Labor': 8,
#  'Statistics': 11,
#  'Data': 8,
#  'Summary': 1,
#  "'This": 18,
#  'Week': 19,
#  'Transcript': 38,
#  'Holder': 2,
#  'Giuliani': 3,
#  'Impeachment': 1,
#  'Talk': 3,
#  'Becomes': 1,
#  'a': 19,
#  'Cynical': 1,
#  'Game': 1,
#  'Preventing': 2,
#  'Flu': 1,
#  'Good': 1,
#  'Health': 14,
#  'Habits': 1,
#  'Can': 6,
#  'Help': 1,
#  'Germs': 1,
#  'Las': 2,
#  'Vegas': 2,
#  'campaign': 6,
#  'rally': 2,
#  'MoveOn.org': 4,
#  'Action': 12,
#  '10': 5,
#  'things': 3,
#  'know': 4,
#  'about': 4,
#  'McCain': 23,
#  'Rand': 6,
#  'Paul': 11,
#  'Campaigns': 3,
#  'Iowa': 1,
#  'for': 51,
#  'Miller-Meeks': 1,
#  'Hispanic': 1,
#  'Populations': 1,
#  'Share': 1,
#  'Wealth': 1,
#  'Likely': 1,
#  'Increase': 1,
#  '2025': 1,
#  'Hillary': 13,
#  'Clinton': 21,
#  'guns': 2,
#  'exceed': 1,
#  'next': 1,
#  'nine': 1,
#  'categories': 1,
#  'as': 17,
#  'leading': 1,
#  'cause': 1,
#  'death': 1,
#  'young': 2,
#  'black': 1,
#  'men': 1,
#  'Already': 1,
#  'lost': 1,
#  'decade': 1,
#  'Working-age': 1,
#  'household': 1,
#  'income': 2,
#  'down': 2,
#  'more': 3,
#  'than': 3,
#  '%': 2,
#  'since': 4,
#  '2000': 1,
#  'U.S.': 27,
#  'Senate': 28,
#  'Supreme': 3,
#  'Court': 3,
#  'Nominations': 1,
#  'present-1789': 1,
#  'PolitiFact': 2,
#  '’': 42,
#  's': 33,
#  'annotated': 6,
#  'transcript': 9,
#  'second': 3,
#  'presidential': 11,
#  'debate': 23,
#  'Obamas': 3,
#  'on': 89,
#  'capandtrade': 1,
#  'costs': 1,
#  'Des': 3,
#  'Moines': 3,
#  'Register': 4,
#  'Tonight': 1,
#  'Show': 3,
#  'with': 17,
#  'Jay': 2,
#  'Leno': 1,
#  'Pelosi': 3,
#  'Gates': 2,
#  'Losing': 1,
#  'Ground': 1,
#  'Foreclosures': 2,
#  'Subprime': 2,
#  'Market': 2,
#  'Their': 1,
#  'Cost': 2,
#  'Homeowners': 1,
#  'Joint': 1,
#  'DHS': 1,
#  'ODNI': 1,
#  'Election': 6,
#  'Security': 8,
#  'Statement': 6,
#  'Roll': 6,
#  'Call': 7,
#  'Votes': 6,
#  '110th': 2,
#  'Congress': 18,
#  'Palin-Huey': 1,
#  'Employment': 6,
#  'Hours': 3,
#  'Earnings': 3,
#  'from': 15,
#  'Current': 3,
#  'survey': 3,
#  '(': 24,
#  ')': 24,
#  'Home': 3,
#  'Page': 3,
#  'No': 5,
#  'We': 9,
#  't': 3,
#  '?': 13,
#  'Or': 1,
#  'Won': 1,
#  'Barack': 18,
#  'Obama': 59,
#  'Remarks': 26,
#  'St.': 2,
#  'letter': 2,
#  'Chaffetz': 1,
#  'Cummings': 2,
#  'Arena': 1,
#  '-': 10,
#  'Politico': 1,
#  "'s": 35,
#  'daily': 1,
#  'policymakers': 1,
#  'opinion': 1,
#  'shapers': 1,
#  'Economic': 6,
#  'Burden': 1,
#  'Caused': 1,
#  'Tax': 14,
#  'Code': 2,
#  'Complexity': 1,
#  'McDonnell': 1,
#  'Letter': 3,
#  'Urges': 2,
#  'Delay': 1,
#  'Virginia': 2,
#  'Offshore': 1,
#  'Energy': 8,
#  'Exploration': 1,
#  'Development': 1,
#  'To': 7,
#  'people': 2,
#  'who': 1,
#  'are': 2,
#  'undocumented': 1,
#  'This': 2,
#  'is': 7,
#  'your': 3,
#  'country': 1,
#  'too': 1,
#  '.': 21,
#  'AP': 1,
#  'interview': 5,
#  'Change': 4,
#  'Believe': 3,
#  'In': 13,
#  'Infrastructure': 1,
#  'Report': 9,
#  'Card': 2,
#  '2005': 3,
#  'Task': 2,
#  'Force': 3,
#  'Lone': 1,
#  'Democrat': 1,
#  'Eye': 1,
#  'Trafficking': 1,
#  'Law': 2,
#  'Dr.': 1,
#  'James': 1,
#  'Dobson': 1,
#  'McSame': 1,
#  'Bush': 4,
#  'john.he.is': 1,
#  'counterterrorism': 1,
#  'at': 19,
#  'Stanford': 1,
#  'University': 3,
#  'iQ': 1,
#  'media': 1,
#  'Clip': 1,
#  'Player': 1,
#  'President': 39,
#  'Increasing': 1,
#  'Oversight': 2,
#  'Manipulation': 1,
#  'Oil': 2,
#  'Markets': 1,
#  'Army': 1,
#  'Involvement': 1,
#  'Motorsports': 1,
#  'UN': 1,
#  'Refugee': 2,
#  'Agency': 1,
#  'welcomes': 1,
#  'arrival': 1,
#  '10,000th': 1,
#  'Syrian': 1,
#  'refugee': 1,
#  'resettled': 1,
#  'Watch': 1,
#  'replay': 1,
#  'Fox': 6,
#  '5': 3,
#  'p.m.': 1,
#  'It': 3,
#  'Time': 2,
#  'Do': 1,
#  'Its': 1,
#  'Job': 3,
#  '–': 12,
#  'Congressman': 4,
#  'Mike': 6,
#  'Honda': 1,
#  'Medium': 6,
#  'Ralph': 2,
#  'Nader': 1,
#  'Quite': 1,
#  'Clear': 1,
#  'He': 5,
#  'Corporate': 1,
#  'Candidate': 4,
#  'Z': 1,
#  'Marco': 2,
#  'Rubio': 3,
#  'Ted': 3,
#  'Cruz': 3,
#  'voted': 1,
#  'defense': 1,
#  'cuts': 2,
#  'budget': 2,
#  'proposal': 1,
#  'Births': 1,
#  'Preliminary': 3,
#  'Ratings': 3,
#  'Before': 1,
#  'leaving': 1,
#  'governor': 1,
#  'office': 1,
#  '2006': 4,
#  'Mitt': 4,
#  'staff': 1,
#  'eliminated': 1,
#  'e-mail': 1,
#  'records': 1,
#  'Milwaukee': 1,
#  'Crist': 1,
#  'experience': 1,
#  'be': 2,
#  'vice': 1,
#  'president': 1,
#  'Strong': 1,
#  'Words': 2,
#  'Ohio': 1,
#  'On': 4,
#  'LexisNexis': 4,
#  'R': 4,
#  'Publisher': 4,
#  '“': 8,
#  'Dictionary': 1,
#  '”': 8,
#  'Taxes': 5,
#  'Memory': 1,
#  'Lapse': 1,
#  'Seeks': 1,
#  'Distance': 1,
#  'From': 1,
#  "'Advisor": 1,
#  'With': 5,
#  'Past': 1,
#  'Ties': 1,
#  'Mafia': 1,
#  'Gross': 3,
#  'Domestic': 2,
#  'Product': 4,
#  'Percent': 2,
#  'change': 1,
#  'preceding': 1,
#  'period': 1,
#  'Who': 2,
#  'Benefits': 2,
#  'Child': 2,
#  'Proposals': 2,
#  'Organizing': 2,
#  'Presidential': 7,
#  'Return': 1,
#  'Viral': 1,
#  'Email': 4,
#  'Rep.': 5,
#  'Ryan': 3,
#  'International': 4,
#  'Interview': 8,
#  'Sen': 3,
#  'John': 12,
#  'radio': 2,
#  'ad': 4,
#  'New': 15,
#  'Strategy': 1,
#  'Afghanistan': 3,
#  'Pakistan': 1,
#  'At': 3,
#  'hotel': 1,
#  'site': 2,
#  'immigrant': 1,
#  'workers': 1,
#  'wary': 1,
#  'Analysis': 5,
#  'Chairman': 1,
#  'Mark': 4,
#  'America': 11,
#  'Healthy': 2,
#  'Future': 2,
#  'Amended': 1,
#  'Comparison': 1,
#  'Full': 5,
#  "'Meet": 1,
#  'Session': 3,
#  'Rudy': 1,
#  'McKay': 1,
#  'Napolitano': 1,
#  'Salazar': 1,
#  'Allen': 2,
#  'Missing': 1,
#  'Teen-Ager': 1,
#  'Found': 1,
#  'Jersey': 2,
#  'text': 1,
#  'Jeff': 1,
#  'Flake': 2,
#  'speech': 4,
#  'Biden': 3,
#  'Rising': 1,
#  'Generation': 1,
#  'Global': 1,
#  'Challenges': 2,
#  'Browse': 2,
#  'Congressional': 4,
#  'Bills': 2,
#  'Taxable': 1,
#  'Estates': 1,
#  'Estate': 3,
#  'Liability': 1,
#  'Average': 2,
#  'Rate': 2,
#  'By': 4,
#  'Size': 1,
#  'Issues': 2,
#  'Following': 1,
#  'Conversation': 1,
#  'Musharraf': 1,
#  'Jobs': 5,
#  'remarks': 2,
#  'Philadelphia': 1,
#  'Krugman': 1,
#  'calls': 2,
#  'health': 6,
#  'care': 4,
#  'bill': 8,
#  'similar': 1,
#  'law': 2,
#  'Massachusetts': 4,
#  'US': 9,
#  'Accountability': 1,
#  'Office': 16,
#  'Committees': 1,
#  'Philando': 1,
#  'Castile': 1,
#  'Had': 1,
#  'Been': 2,
#  'Stopped': 1,
#  '52': 1,
#  'Times': 2,
#  'Police': 2,
#  'Regular': 1,
#  'More': 2,
#  'Dragging': 1,
#  'Up': 3,
#  'Rear': 1,
#  'Arkansas': 1,
#  'Bows': 1,
#  'Pressures': 1,
#  'Put': 3,
#  'Schools': 1,
#  'Test': 1,
#  '05/27/99': 1,
#  'Committee': 7,
#  'Judiciary': 1,
#  'Bright': 1,
#  'Horizons': 1,
#  '&': 8,
#  'Family': 2,
#  'Solutions': 1,
#  'MidOct': 1,
#  'Paycheck': 1,
#  'Troops': 1,
#  'if': 1,
#  'Shuts': 1,
#  'Down': 3,
#  'Lawmaker': 1,
#  'Income': 4,
#  'Accounts': 1,
#  'Table': 3,
#  '175': 1,
#  'Relation': 1,
#  'Enduring': 1,
#  'Strength': 2,
#  'Debt': 2,
#  'Day': 4,
#  'Symbol': 1,
#  'Washington': 3,
#  'Arrogant': 1,
#  'Culture': 1,
#  'Borrowing': 1,
#  'Spending': 3,
#  'Boehner': 6,
#  'Op-Ed': 2,
#  'Townhall.com': 1,
#  'Former': 2,
#  'Vice': 2,
#  'Dick': 2,
#  'Cheney': 2,
#  'Blue-Ribbon': 1,
#  'Panel': 3,
#  'Republican': 9,
#  'response': 1,
#  'Weekly': 4,
#  'address': 1,
#  'Colbert': 2,
#  '105th': 1,
#  'Striking': 1,
#  'it': 4,
#  'Richer': 1,
#  'Evolution': 1,
#  'Top': 5,
#  'Incomes': 1,
#  'update': 1,
#  '2007': 8,
#  'estimates': 1,
#  'Outlook': 15,
#  'Skype': 13,
#  'Bing': 13,
#  'Breaking': 15,
#  'Latest': 14,
#  'Videos': 14,
#  'Space': 1,
#  'Threat': 1,
#  'How': 2,
#  'Missiles': 1,
#  'Could': 1,
#  'Target': 3,
#  'Satellites': 1,
#  'Openings': 1,
#  'Turnover': 1,
#  'Survey': 3,
#  'Release': 1,
#  'Goolsbee': 1,
#  'Brown': 1,
#  'Corker': 1,
#  'Candidates': 1,
#  'Plans': 1,
#  'considers': 1,
#  '3,000': 1,
#  'troops': 2,
#  '3rd': 1,
#  'said': 2,
#  'what': 3,
#  'meant': 1,
#  'Joni': 1,
#  'Ernst': 1,
#  'Promises': 2,
#  'Testimony': 2,
#  'Alternative': 1,
#  'Minimum': 1,
#  'Criticizes': 2,
#  'Lobbyists': 2,
#  'SECRET': 1,
#  'VIDEO': 2,
#  'Tells': 1,
#  'Millionaire': 1,
#  'Donors': 1,
#  'What': 3,
#  'REALLY': 1,
#  'Thinks': 1,
#  'Voters': 1,
#  'Peace': 3,
#  'Through': 1,
#  'Pride': 1,
#  'vs.': 2,
#  'Enemy-Centric': 1,
#  'Policy': 6,
#  'Sen.': 8,
#  'Dianne': 1,
#  'Feinstein': 1,
#  'Rogers': 1,
#  'There': 1,
#  'another': 1,
#  'choice': 1,
#  'Gov': 2,
#  'Gary': 1,
#  'Johnson': 1,
#  'Florida': 1,
#  'Ask': 2,
#  'HHS': 1,
#  'Protect': 2,
#  'Floridians': 2,
#  'High': 2,
#  'Insurance': 4,
#  'Premiums': 1,
#  'Marketplace': 1,
#  'Hampshire': 1,
#  'Sale': 1,
#  'Etch': 1,
#  'Sketch': 1,
#  'Brand': 1,
#  'For': 5,
#  'Launches': 1,
#  'Television': 3,
#  'Remember': 1,
#  'Gravel': 1,
#  'filed': 1,
#  'behalf': 1,
#  'Exploratory': 1,
#  'School': 2,
#  'kids': 1,
#  'taught': 1,
#  'praise': 1,
#  'Reps': 1,
#  'Cole': 1,
#  'Interviewed': 2,
#  'MSNBC': 3,
#  'Local': 1,
#  'Headlines': 1,
#  'Hawaii': 1,
#  'Michael': 4,
#  'Bennet': 1,
#  'U.S': 4,
#  'Senator': 15,
#  'Kentucky': 2,
#  'H.R.6060': 1,
#  '109th': 2,
#  '2005-2006': 1,
#  'Department': 8,
#  'State': 4,
#  'Authorities': 1,
#  'spreadsheet': 1,
#  'key': 2,
#  'indicators': 1,
#  'OECD': 1,
#  '2009': 6,
#  'expenditures': 2,
#  'per': 1,
#  'capita': 1,
#  'Transcripts': 10,
#  'Without': 1,
#  'Coverage': 2,
#  'Too': 2,
#  'Little': 1,
#  'Late': 1,
#  'Rep': 4,
#  'Pence': 2,
#  'Web': 3,
#  'Border': 3,
#  'Opportunity': 3,
#  'Immigration': 2,
#  'Modernization': 1,
#  'passed': 1,
#  'Blue': 3,
#  'Fund': 2,
#  'Pledge': 1,
#  'Allegiance': 1,
#  'E-mail': 1,
#  'spoke': 1,
#  'up': 2,
#  'early': 2,
#  'apologized': 1,
#  'showed': 1,
#  'weakness': 1,
#  'Iran': 2,
#  'Urban': 3,
#  'League': 1,
#  'Conference': 2,
#  'Friend': 1,
#  'Israel': 2,
#  'also': 1,
#  'woos': 1,
#  'Palestinians': 1,
#  'Visiting': 1,
#  'focuses': 1,
#  'Israels': 1,
#  'right': 1,
#  'defend': 1,
#  'itself': 1,
#  'Saudi': 1,
#  'Arabia': 1,
#  'Insight': 1,
#  'FrontPage': 1,
#  'Magazine': 2,
#  'Gitmo': 1,
#  'inspires': 1,
#  'jihadists': 1,
#  'RAW': 1,
#  'DATA': 1,
#  'Center': 6,
#  'Critical': 1,
#  'Mention': 1,
#  'Monthly': 2,
#  'Treasury': 2,
#  'Receipts': 1,
#  'Outlays': 1,
#  'An': 3,
#  'Agenda': 1,
#  'MiddleClass': 1,
#  'Success': 1,
#  'Is': 4,
#  'End': 1,
#  'Sight': 1,
#  'Supermax': 1,
#  'Tim': 2,
#  'Kaine': 3,
#  'Speech': 4,
#  'Spanish': 1,
#  'an': 3,
#  'Arizona': 2,
#  'Rally': 1,
#  'Read': 2,
#  'Now': 1,
#  'Tough': 1,
#  'Hedge-Fund': 1,
#  'Does': 2,
#  "n't": 7,
#  'Match': 1,
#  'His': 4,
#  'Crime': 2,
#  'Chicago': 1,
#  'Explore': 1,
#  'community': 1,
#  'York': 6,
#  'Results': 2,
#  'November': 2,
#  '7': 2,
#  'Sanders': 5,
#  'Supports': 1,
#  'Gun': 5,
#  'Safety': 2,
#  'Bill': 8,
#  'Sasse': 1,
#  'Trade': 2,
#  'War': 5,
#  'Review': 2,
#  'Centers': 1,
#  'Disease': 1,
#  'Control': 2,
#  'Prevention': 2,
#  'NRA': 2,
#  'David': 3,
#  'Keene': 1,
#  'Rejects': 1,
#  'Approach': 1,
#  '|': 4,
#  'PBS': 2,
#  'NewsHour': 2,
#  'Jan.': 1,
#  '15': 1,
#  '2013': 4,
#  'Let': 1,
#  'Not': 3,
#  'Be': 2,
#  'Civil': 2,
#  'cable': 1,
#  'cited': 1,
#  'article': 1,
#  'industry': 2,
#  'study': 1,
#  'Education': 3,
#  'History': 2,
#  'Bob': 2,
#  'Barr': 1,
#  "'FOX": 1,
#  'Sunday': 4,
#  'first': 4,
#  'Trump-Clinton': 1,
#  'Role': 1,
#  'Patrol': 1,
#  'urges': 1,
#  'minimum-wage': 1,
#  'hike': 1,
#  'Lead': 1,
#  'Over': 3,
#  'Shrinks': 1,
#  '3': 1,
#  'Points': 1,
#  'NBC': 1,
#  'News/WSJ': 1,
#  'Poll': 1,
#  'FindArticles.com': 1,
#  'All': 2,
#  'Nobel': 1,
#  'Prizes': 1,
#  'H.R.1025': 1,
#  '103rd': 2,
#  '1993-1994': 1,
#  'Brady': 1,
#  'Handgun': 1,
#  'Violence': 1,
#  'Text': 8,
#  'Campaign': 5,
#  'Launch': 1,
#  'Hagee': 1,
#  'discusses': 1,
#  'Catholic': 2,
#  'Church': 1,
#  'Palin': 7,
#  'WolfKilling': 2,
#  'Record': 2,
#  'Hill': 2,
#  'Go': 2,
#  'natural': 1,
#  'go': 2,
#  'nuclear': 2,
#  'declare': 1,
#  'English': 1,
#  'national': 3,
#  'language': 1,
#  'Declining': 1,
#  'Dynamism': 1,
#  'Look': 1,
#  'Metros': 1,
#  'Nexis®': 1,
#  'Sign': 1,
#  'Vern': 1,
#  'Buchanan': 1,
#  'Twitter': 10,
#  'Ivanka': 1,
#  'Father': 1,
#  'feels': 1,
#  "'vindicated": 1,
#  'after': 1,
#  'Comey': 1,
#  'hearing': 2,
#  'touts': 1,
#  "'Gang": 1,
#  '14': 2,
#  'immigration': 2,
#  'reform': 2,
#  'Planned': 3,
#  'Parenthood®': 2,
#  'CPD': 1,
#  'Debate': 7,
#  'Czars': 1,
#  'Than': 1,
#  'Romanovs': 1,
#  'Impact': 2,
#  'Described': 1,
#  'Advisors': 1,
#  'Workers': 1,
#  'Distribution': 2,
#  'Federal': 6,
#  'Cash': 2,
#  'Percentile': 1,
#  'universal': 1,
#  'but': 1,
#  'no': 2,
#  'guarantee': 1,
#  'addresses': 1,
#  'concerns': 1,
#  'Chairmans': 1,
#  'Americas': 3,
#  'Op-ed': 1,
#  'Reflects': 1,
#  'Title': 1,
#  'IX': 1,
#  'Adm.': 1,
#  'Mullen': 1,
#  'Demands': 1,
#  'Investigation': 1,
#  'into': 3,
#  'Loan': 1,
#  'Discrimination': 1,
#  'Building': 1,
#  '‘': 4,
#  'Growth': 2,
#  'Fairness': 1,
#  'Economy': 5,
#  'Topic': 1,
#  'Regain': 1,
#  'Footing': 1,
#  'AUTOS': 1,
#  'Dinosaur': 1,
#  'Hunter': 1,
#  '3/8/14': 1,
#  'Rob': 3,
#  'Portman': 3,
#  'R-OH': 1,
#  'delivers': 1,
#  'Address': 2,
#  'jobs': 2,
#  'Forget': 1,
#  'Kiev': 1,
#  'Real': 1,
#  'Fight': 3,
#  'Will': 2,
#  'Crimea': 1,
#  'Public': 7,
#  'financial': 2,
#  'disclosure': 1,
#  'report': 1,
#  'Nashville': 1,
#  'H1N1': 1,
#  'vaccinations': 1,
#  'offered': 1,
#  'Guantanamo': 1,
#  'Bay': 1,
#  'detainees': 1,
#  'Inquiry': 1,
#  'Sought': 1,
#  'Use': 2,
#  'CNN': 5,
#  'Don': 1,
#  'Lemon': 1,
#  "O'Reilly": 1,
#  'Criticism': 1,
#  'Of': 3,
#  'Black': 1,
#  'Community': 1,
#  'Far': 1,
#  'Enough': 2,
#  '2010': 2,
#  'Give': 1,
#  'Me': 1,
#  'Break': 1,
#  'Americans': 5,
#  'Food': 2,
#  '2011': 8,
#  'H.R.2122': 1,
#  '106th': 1,
#  '1999-2000': 1,
#  'Mandatory': 1,
#  'Background': 2,
#  'Check': 1,
#  'Noted': 1,
#  'Quoted': 1,
#  'Associated': 2,
#  'Hits': 2,
#  'NAFTA': 1,
#  'Support': 1,
#  'Bernie': 3,
#  'really': 1,
#  'socialist': 1,
#  'Eisenhower': 1,
#  'Madeleine': 1,
#  'Albright': 1,
#  'Lindsey': 1,
#  'Graham': 2,
#  'Kent': 1,
#  'Conrad': 1,
#  'Cote': 1,
#  'Oct.': 1,
#  '11': 1,
#  'Levin': 1,
#  'McCaffrey': 1,
#  'Myers': 1,
#  'roundtable': 1,
#  'Foreign': 3,
#  'Military': 1,
#  'Aid': 1,
#  'Major': 1,
#  'Recipient': 1,
#  'Country': 2,
#  'proposed': 1,
#  'Lynne': 1,
#  'Bernabei': 1,
#  'consultant': 1,
#  'promised': 1,
#  'halve': 1,
#  'federal': 2,
#  ...}

# %%
# %timeit -n1 x = 4
# Out:
# 129 ns ± 70 ns per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
len(true_title_words_2)
# Out:
# 215757

# %%
true_title_words = np.append(true_title_words, true_title_words_2)

# %%
true_title_counter = dict(collections.Counter(true_title_words))

# %%
print(len(true_title_words))
# Out:
# 221353

# %%
true_title_counter
# Out:
# {'National': 46,
#  'Federation': 1,
#  'of': 2311,
#  'Independent': 8,
#  'Business': 17,
#  'comments': 15,
#  'in': 2097,
#  'Fayetteville': 1,
#  'NC': 1,
#  'Romney': 9,
#  'makes': 46,
#  'pitch': 2,
#  ',': 3011,
#  'hoping': 2,
#  'to': 3018,
#  'close': 10,
#  'deal': 12,
#  ':': 3656,
#  'Elections': 4,
#  'The': 1821,
#  'Rocky': 8,
#  'Mountain': 2,
#  'News': 168,
#  'Democratic': 16,
#  'Leaders': 4,
#  'Say': 41,
#  'House': 100,
#  'Democrats': 5,
#  'Are': 387,
#  'United': 22,
#  'Against': 42,
#  'GOP': 9,
#  'Default': 2,
#  'Act': 31,
#  'Budget': 11,
#  'the': 3199,
#  'States': 17,
#  'Government': 8,
#  'FY': 2,
#  '2008': 11,
#  'Donald': 52,
#  'Trump': 176,
#  'exaggerates': 1,
#  'when': 37,
#  'he': 115,
#  'says': 163,
#  'China': 7,
#  'has': 88,
#  "'total": 2,
#  'control': 6,
#  "'": 3601,
#  'over': 89,
#  'North': 40,
#  'Korea': 1,
#  '25th': 8,
#  'Amendment': 4,
#  '子供たちのコト。私のコト。': 1,
#  'Briefing': 4,
#  'by': 288,
#  'White': 61,
#  'Press': 17,
#  'Secretary': 6,
#  'Robert': 66,
#  'Gibbs': 2,
#  '9/10/09': 1,
#  'A': 506,
#  'Solar': 5,
#  'Grand': 6,
#  'Plan': 27,
#  'Scientific': 2,
#  'American': 119,
#  'Covering': 2,
#  'Young': 33,
#  'Adults': 1,
#  'Under': 26,
#  'Affordable': 12,
#  'Care': 25,
#  'Importance': 2,
#  'Outreach': 1,
#  'and': 3471,
#  'Medicaid': 2,
#  'Expansion': 1,
#  'Harry': 294,
#  'Reid': 6,
#  'Says': 338,
#  'Should': 42,
#  '``': 597,
#  'Stop': 38,
#  'Crying': 11,
#  "''": 609,
#  'About': 534,
#  'Reconciliation': 5,
#  'Political': 18,
#  'TV': 318,
#  'Ad': 29,
#  'Archive': 6,
#  '»': 7,
#  'PolAd': 4,
#  'Bureau': 4,
#  'Labor': 20,
#  'Statistics': 12,
#  'Data': 8,
#  'Summary': 1,
#  "'This": 51,
#  'Week': 101,
#  'Transcript': 38,
#  'Holder': 2,
#  'Giuliani': 3,
#  'Impeachment': 1,
#  'Talk': 50,
#  'Becomes': 7,
#  'a': 1786,
#  'Cynical': 2,
#  'Game': 112,
#  'Preventing': 2,
#  'Flu': 2,
#  'Good': 73,
#  'Health': 45,
#  'Habits': 1,
#  'Can': 115,
#  'Help': 38,
#  'Germs': 1,
#  'Las': 59,
#  'Vegas': 77,
#  'campaign': 14,
#  'rally': 3,
#  'MoveOn.org': 4,
#  'Action': 25,
#  '10': 149,
#  'things': 19,
#  'know': 54,
#  'about': 195,
#  'McCain': 31,
#  'Rand': 7,
#  'Paul': 72,
#  'Campaigns': 3,
#  'Iowa': 4,
#  'for': 1465,
#  'Miller-Meeks': 1,
#  'Hispanic': 1,
#  'Populations': 1,
#  'Share': 33,
#  'Wealth': 1,
#  'Likely': 7,
#  'Increase': 2,
#  '2025': 1,
#  'Hillary': 26,
#  'Clinton': 33,
#  'guns': 2,
#  'exceed': 1,
#  'next': 13,
#  'nine': 3,
#  'categories': 2,
#  'as': 464,
#  'leading': 3,
#  'cause': 6,
#  'death': 53,
#  'young': 13,
#  'black': 6,
#  'men': 10,
#  'Already': 27,
#  'lost': 7,
#  'decade': 3,
#  'Working-age': 1,
#  'household': 1,
#  'income': 2,
#  'down': 43,
#  'more': 58,
#  'than': 24,
#  '%': 20,
#  'since': 24,
#  '2000': 1,
#  'U.S.': 45,
#  'Senate': 29,
#  'Supreme': 5,
#  'Court': 11,
#  'Nominations': 57,
#  'present-1789': 1,
#  'PolitiFact': 2,
#  '’': 3265,
#  's': 1431,
#  'annotated': 6,
#  'transcript': 9,
#  'second': 13,
#  'presidential': 12,
#  'debate': 25,
#  'Obamas': 3,
#  'on': 1823,
#  'capandtrade': 1,
#  'costs': 3,
#  'Des': 4,
#  'Moines': 3,
#  'Register': 4,
#  'Tonight': 22,
#  'Show': 242,
#  'with': 902,
#  'Jay': 29,
#  'Leno': 3,
#  'Pelosi': 4,
#  'Gates': 8,
#  'Losing': 13,
#  'Ground': 3,
#  'Foreclosures': 2,
#  'Subprime': 2,
#  'Market': 4,
#  'Their': 296,
#  'Cost': 14,
#  'Homeowners': 1,
#  'Joint': 8,
#  'DHS': 1,
#  'ODNI': 1,
#  'Election': 8,
#  'Security': 18,
#  'Statement': 21,
#  'Roll': 9,
#  'Call': 36,
#  'Votes': 6,
#  '110th': 2,
#  'Congress': 22,
#  'Palin-Huey': 1,
#  'Employment': 6,
#  'Hours': 9,
#  'Earnings': 3,
#  'from': 345,
#  'Current': 11,
#  'survey': 3,
#  '(': 472,
#  ')': 471,
#  'Home': 81,
#  'Page': 15,
#  'No': 155,
#  'We': 174,
#  't': 193,
#  '?': 705,
#  'Or': 6,
#  'Won': 29,
#  'Barack': 34,
#  'Obama': 95,
#  'Remarks': 29,
#  'St.': 11,
#  'letter': 7,
#  'Chaffetz': 1,
#  'Cummings': 3,
#  'Arena': 5,
#  '-': 179,
#  'Politico': 1,
#  "'s": 3364,
#  'daily': 4,
#  'policymakers': 1,
#  'opinion': 1,
#  'shapers': 1,
#  'Economic': 6,
#  'Burden': 1,
#  'Caused': 6,
#  'Tax': 15,
#  'Code': 5,
#  'Complexity': 1,
#  'McDonnell': 2,
#  'Letter': 22,
#  'Urges': 3,
#  'Delay': 2,
#  'Virginia': 2,
#  'Offshore': 1,
#  'Energy': 10,
#  'Exploration': 1,
#  'Development': 10,
#  'To': 389,
#  'people': 17,
#  'who': 68,
#  'are': 145,
#  'undocumented': 2,
#  'This': 359,
#  'is': 473,
#  'your': 29,
#  'country': 7,
#  'too': 8,
#  '.': 416,
#  'AP': 4,
#  'interview': 28,
#  'Change': 15,
#  'Believe': 21,
#  'In': 361,
#  'Infrastructure': 1,
#  'Report': 45,
#  'Card': 21,
#  '2005': 3,
#  'Task': 3,
#  'Force': 9,
#  'Lone': 2,
#  'Democrat': 1,
#  'Eye': 53,
#  'Trafficking': 3,
#  'Law': 33,
#  'Dr.': 16,
#  'James': 220,
#  'Dobson': 1,
#  'McSame': 1,
#  'Bush': 32,
#  'john.he.is': 1,
#  'counterterrorism': 1,
#  'at': 1167,
#  'Stanford': 2,
#  'University': 7,
#  'iQ': 1,
#  'media': 22,
#  'Clip': 13,
#  'Player': 12,
#  'President': 67,
#  'Increasing': 1,
#  'Oversight': 2,
#  'Manipulation': 1,
#  'Oil': 5,
#  'Markets': 1,
#  'Army': 1,
#  'Involvement': 1,
#  'Motorsports': 1,
#  'UN': 1,
#  'Refugee': 3,
#  'Agency': 1,
#  'welcomes': 5,
#  'arrival': 2,
#  '10,000th': 1,
#  'Syrian': 3,
#  'refugee': 2,
#  'resettled': 1,
#  'Watch': 320,
#  'replay': 1,
#  'Fox': 51,
#  '5': 184,
#  'p.m.': 1,
#  'It': 359,
#  'Time': 223,
#  'Do': 113,
#  'Its': 43,
#  'Job': 17,
#  '–': 354,
#  'Congressman': 4,
#  'Mike': 34,
#  'Honda': 1,
#  'Medium': 68,
#  'Ralph': 6,
#  'Nader': 1,
#  'Quite': 3,
#  'Clear': 8,
#  'He': 282,
#  'Corporate': 1,
#  'Candidate': 4,
#  'Z': 12,
#  'Marco': 2,
#  'Rubio': 3,
#  'Ted': 6,
#  'Cruz': 11,
#  'voted': 1,
#  'defense': 2,
#  'cuts': 6,
#  'budget': 2,
#  'proposal': 6,
#  'Births': 3,
#  'Preliminary': 3,
#  'Ratings': 24,
#  'Before': 95,
#  'leaving': 14,
#  'governor': 1,
#  'office': 6,
#  '2006': 4,
#  'Mitt': 4,
#  'staff': 5,
#  'eliminated': 6,
#  'e-mail': 1,
#  'records': 2,
#  'Milwaukee': 1,
#  'Crist': 1,
#  'experience': 6,
#  'be': 94,
#  'vice': 1,
#  'president': 5,
#  'Strong': 12,
#  'Words': 13,
#  'Ohio': 3,
#  'On': 270,
#  'LexisNexis': 4,
#  'R': 9,
#  'Publisher': 4,
#  '“': 270,
#  'Dictionary': 1,
#  '”': 315,
#  'Taxes': 5,
#  'Memory': 4,
#  'Lapse': 1,
#  'Seeks': 3,
#  'Distance': 3,
#  'From': 404,
#  "'Advisor": 1,
#  'With': 911,
#  'Past': 29,
#  'Ties': 5,
#  'Mafia': 1,
#  'Gross': 5,
#  'Domestic': 19,
#  'Product': 15,
#  'Percent': 4,
#  'change': 2,
#  'preceding': 1,
#  'period': 1,
#  'Who': 229,
#  'Benefits': 3,
#  'Child': 104,
#  'Proposals': 3,
#  'Organizing': 3,
#  'Presidential': 9,
#  'Return': 84,
#  'Viral': 14,
#  'Email': 7,
#  'Rep.': 5,
#  'Ryan': 171,
#  'International': 12,
#  'Interview': 61,
#  'Sen': 3,
#  'John': 204,
#  'radio': 4,
#  'ad': 13,
#  'New': 640,
#  'Strategy': 3,
#  'Afghanistan': 3,
#  'Pakistan': 1,
#  'At': 139,
#  'hotel': 4,
#  'site': 5,
#  'immigrant': 3,
#  'workers': 1,
#  'wary': 1,
#  'Analysis': 7,
#  'Chairman': 1,
#  'Mark': 55,
#  'America': 74,
#  'Healthy': 11,
#  'Future': 29,
#  'Amended': 1,
#  'Comparison': 4,
#  'Full': 61,
#  "'Meet": 1,
#  'Session': 9,
#  'Rudy': 1,
#  'McKay': 1,
#  'Napolitano': 1,
#  'Salazar': 1,
#  'Allen': 26,
#  'Missing': 15,
#  'Teen-Ager': 1,
#  'Found': 36,
#  'Jersey': 52,
#  'text': 2,
#  'Jeff': 23,
#  'Flake': 2,
#  'speech': 23,
#  'Biden': 5,
#  'Rising': 4,
#  'Generation': 7,
#  'Global': 7,
#  'Challenges': 4,
#  'Browse': 2,
#  'Congressional': 5,
#  'Bills': 3,
#  'Taxable': 1,
#  'Estates': 2,
#  'Estate': 4,
#  'Liability': 1,
#  'Average': 3,
#  'Rate': 2,
#  'By': 104,
#  'Size': 6,
#  'Issues': 23,
#  'Following': 50,
#  'Conversation': 6,
#  'Musharraf': 1,
#  'Jobs': 9,
#  'remarks': 5,
#  'Philadelphia': 1,
#  'Krugman': 1,
#  'calls': 44,
#  'health': 20,
#  'care': 13,
#  'bill': 9,
#  'similar': 2,
#  'law': 3,
#  'Massachusetts': 4,
#  'US': 24,
#  'Accountability': 2,
#  'Office': 32,
#  'Committees': 1,
#  'Philando': 1,
#  'Castile': 1,
#  'Had': 78,
#  'Been': 56,
#  'Stopped': 6,
#  '52': 2,
#  'Times': 53,
#  'Police': 24,
#  'Regular': 9,
#  'More': 330,
#  'Dragging': 2,
#  'Up': 355,
#  'Rear': 1,
#  'Arkansas': 3,
#  'Bows': 1,
#  'Pressures': 1,
#  'Put': 13,
#  'Schools': 3,
#  'Test': 12,
#  '05/27/99': 1,
#  'Committee': 9,
#  'Judiciary': 1,
#  'Bright': 6,
#  'Horizons': 1,
#  '&': 855,
#  'Family': 187,
#  'Solutions': 2,
#  'MidOct': 1,
#  'Paycheck': 3,
#  'Troops': 3,
#  'if': 15,
#  'Shuts': 12,
#  'Down': 102,
#  'Lawmaker': 2,
#  'Income': 8,
#  'Accounts': 5,
#  'Table': 9,
#  '175': 4,
#  'Relation': 1,
#  'Enduring': 2,
#  'Strength': 4,
#  'Debt': 4,
#  'Day': 218,
#  'Symbol': 1,
#  'Washington': 21,
#  'Arrogant': 2,
#  'Culture': 8,
#  'Borrowing': 2,
#  'Spending': 12,
#  'Boehner': 6,
#  'Op-Ed': 4,
#  'Townhall.com': 1,
#  'Former': 55,
#  'Vice': 5,
#  'Dick': 13,
#  'Cheney': 4,
#  'Blue-Ribbon': 1,
#  'Panel': 5,
#  'Republican': 11,
#  'response': 7,
#  'Weekly': 5,
#  'address': 4,
#  'Colbert': 36,
#  '105th': 1,
#  'Striking': 2,
#  'it': 132,
#  'Richer': 1,
#  'Evolution': 12,
#  'Top': 82,
#  'Incomes': 1,
#  'update': 10,
#  '2007': 8,
#  'estimates': 2,
#  'Outlook': 16,
#  'Skype': 13,
#  'Bing': 13,
#  'Breaking': 25,
#  'Latest': 53,
#  'Videos': 27,
#  'Space': 6,
#  'Threat': 3,
#  'How': 581,
#  'Missiles': 1,
#  'Could': 52,
#  'Target': 15,
#  'Satellites': 1,
#  'Openings': 1,
#  'Turnover': 1,
#  'Survey': 3,
#  'Release': 33,
#  'Goolsbee': 1,
#  'Brown': 100,
#  'Corker': 1,
#  'Candidates': 1,
#  'Plans': 25,
#  'considers': 2,
#  '3,000': 1,
#  'troops': 2,
#  '3rd': 5,
#  'said': 14,
#  'what': 55,
#  'meant': 1,
#  'Joni': 1,
#  'Ernst': 1,
#  'Promises': 13,
#  'Testimony': 4,
#  'Alternative': 1,
#  'Minimum': 1,
#  'Criticizes': 3,
#  'Lobbyists': 2,
#  'SECRET': 2,
#  'VIDEO': 32,
#  'Tells': 42,
#  'Millionaire': 1,
#  'Donors': 1,
#  'What': 304,
#  'REALLY': 2,
#  'Thinks': 26,
#  'Voters': 1,
#  'Peace': 5,
#  'Through': 31,
#  'Pride': 2,
#  'vs.': 19,
#  'Enemy-Centric': 1,
#  'Policy': 10,
#  'Sen.': 8,
#  'Dianne': 1,
#  'Feinstein': 1,
#  'Rogers': 4,
#  'There': 44,
#  'another': 14,
#  'choice': 3,
#  'Gov': 2,
#  'Gary': 9,
#  'Johnson': 68,
#  'Florida': 13,
#  'Ask': 4,
#  'HHS': 1,
#  'Protect': 8,
#  'Floridians': 2,
#  'High': 36,
#  'Insurance': 4,
#  'Premiums': 1,
#  'Marketplace': 1,
#  'Hampshire': 2,
#  'Sale': 21,
#  'Etch': 1,
#  'Sketch': 7,
#  'Brand': 20,
#  'For': 298,
#  'Launches': 11,
#  'Television': 9,
#  'Remember': 11,
#  'Gravel': 1,
#  'filed': 1,
#  'behalf': 1,
#  'Exploratory': 1,
#  'School': 41,
#  'kids': 32,
#  'taught': 3,
#  'praise': 1,
#  'Reps': 1,
#  'Cole': 31,
#  'Interviewed': 2,
#  'MSNBC': 3,
#  'Local': 1,
#  'Headlines': 6,
#  'Hawaii': 20,
#  'Michael': 101,
#  'Bennet': 4,
#  'U.S': 6,
#  'Senator': 15,
#  'Kentucky': 10,
#  'H.R.6060': 1,
#  '109th': 2,
#  '2005-2006': 1,
#  'Department': 8,
#  'State': 15,
#  'Authorities': 1,
#  'spreadsheet': 1,
#  'key': 3,
#  'indicators': 1,
#  'OECD': 1,
#  '2009': 7,
#  'expenditures': 2,
#  'per': 4,
#  'capita': 1,
#  'Transcripts': 10,
#  'Without': 33,
#  'Coverage': 5,
#  'Too': 45,
#  'Little': 86,
#  'Late': 73,
#  'Rep': 12,
#  'Pence': 5,
#  'Web': 4,
#  'Border': 4,
#  'Opportunity': 3,
#  'Immigration': 2,
#  'Modernization': 1,
#  'passed': 2,
#  'Blue': 42,
#  'Fund': 4,
#  'Pledge': 1,
#  'Allegiance': 1,
#  'E-mail': 1,
#  'spoke': 2,
#  'up': 110,
#  'early': 6,
#  'apologized': 2,
#  'showed': 5,
#  'weakness': 1,
#  'Iran': 2,
#  'Urban': 24,
#  'League': 11,
#  'Conference': 3,
#  'Friend': 44,
#  'Israel': 5,
#  'also': 7,
#  'woos': 1,
#  'Palestinians': 1,
#  'Visiting': 8,
#  'focuses': 1,
#  'Israels': 1,
#  'right': 6,
#  'defend': 1,
#  'itself': 2,
#  'Saudi': 3,
#  'Arabia': 2,
#  'Insight': 3,
#  'FrontPage': 1,
#  'Magazine': 35,
#  'Gitmo': 1,
#  'inspires': 4,
#  'jihadists': 1,
#  'RAW': 1,
#  'DATA': 1,
#  'Center': 20,
#  'Critical': 1,
#  'Mention': 1,
#  'Monthly': 3,
#  'Treasury': 3,
#  'Receipts': 1,
#  'Outlays': 1,
#  'An': 48,
#  'Agenda': 2,
#  'MiddleClass': 1,
#  'Success': 7,
#  'Is': 1211,
#  'End': 61,
#  'Sight': 24,
#  'Supermax': 1,
#  'Tim': 19,
#  'Kaine': 3,
#  'Speech': 27,
#  'Spanish': 4,
#  'an': 178,
#  'Arizona': 6,
#  'Rally': 1,
#  'Read': 23,
#  'Now': 115,
#  'Tough': 10,
#  'Hedge-Fund': 1,
#  'Does': 67,
#  "n't": 343,
#  'Match': 11,
#  'His': 499,
#  'Crime': 30,
#  'Chicago': 28,
#  'Explore': 1,
#  'community': 3,
#  'York': 75,
#  'Results': 11,
#  'November': 8,
#  '7': 123,
#  'Sanders': 9,
#  'Supports': 9,
#  'Gun': 21,
#  'Safety': 4,
#  'Bill': 51,
#  'Sasse': 1,
#  'Trade': 3,
#  'War': 48,
#  'Review': 41,
#  'Centers': 1,
#  'Disease': 6,
#  'Control': 9,
#  'Prevention': 3,
#  'NRA': 2,
#  'David': 137,
#  'Keene': 1,
#  'Rejects': 2,
#  'Approach': 2,
#  '|': 34,
#  'PBS': 6,
#  'NewsHour': 2,
#  'Jan.': 2,
#  '15': 72,
#  '2013': 7,
#  'Let': 24,
#  'Not': 179,
#  'Be': 205,
#  'Civil': 5,
#  'cable': 1,
#  'cited': 2,
#  'article': 3,
#  'industry': 4,
#  'study': 1,
#  'Education': 5,
#  'History': 43,
#  'Bob': 22,
#  'Barr': 17,
#  "'FOX": 1,
#  'Sunday': 11,
#  'first': 112,
#  'Trump-Clinton': 1,
#  'Role': 36,
#  'Patrol': 1,
#  'urges': 1,
#  'minimum-wage': 1,
#  'hike': 3,
#  'Lead': 15,
#  'Over': 203,
#  'Shrinks': 1,
#  '3': 185,
#  'Points': 3,
#  'NBC': 38,
#  'News/WSJ': 1,
#  'Poll': 1,
#  'FindArticles.com': 1,
#  'All': 344,
#  'Nobel': 1,
#  'Prizes': 1,
#  'H.R.1025': 1,
#  '103rd': 2,
#  '1993-1994': 1,
#  'Brady': 27,
#  'Handgun': 1,
#  'Violence': 14,
#  'Text': 10,
#  'Campaign': 20,
#  'Launch': 8,
#  'Hagee': 1,
#  'discusses': 6,
#  'Catholic': 3,
#  'Church': 8,
#  'Palin': 22,
#  'WolfKilling': 2,
#  'Record': 10,
#  'Hill': 20,
#  'Go': 53,
#  'natural': 3,
#  'go': 21,
#  'nuclear': 2,
#  'declare': 2,
#  'English': 12,
#  'national': 10,
#  'language': 2,
#  'Declining': 1,
#  'Dynamism': 1,
#  'Look': 165,
#  'Metros': 1,
#  'Nexis®': 1,
#  'Sign': 9,
#  'Vern': 1,
#  'Buchanan': 1,
#  'Twitter': 94,
#  'Ivanka': 20,
#  'Father': 62,
#  'feels': 6,
#  "'vindicated": 1,
#  'after': 321,
#  'Comey': 1,
#  'hearing': 4,
#  'touts': 2,
#  "'Gang": 1,
#  '14': 46,
#  'immigration': 2,
#  'reform': 3,
#  'Planned': 11,
#  'Parenthood®': 2,
#  'CPD': 1,
#  'Debate': 10,
#  'Czars': 1,
#  'Than': 75,
#  'Romanovs': 1,
#  'Impact': 6,
#  'Described': 1,
#  'Advisors': 1,
#  'Workers': 1,
#  'Distribution': 2,
#  'Federal': 7,
#  'Cash': 7,
#  'Percentile': 1,
#  'universal': 1,
#  'but': 62,
#  'no': 31,
#  'guarantee': 1,
#  'addresses': 15,
#  'concerns': 2,
#  'Chairmans': 1,
#  'Americas': 4,
#  'Op-ed': 1,
#  'Reflects': 22,
#  'Title': 14,
#  'IX': 6,
#  'Adm.': 1,
#  'Mullen': 1,
#  'Demands': 6,
#  'Investigation': 13,
#  'into': 54,
#  'Loan': 2,
#  'Discrimination': 2,
#  'Building': 6,
#  '‘': 1396,
#  'Growth': 4,
#  'Fairness': 1,
#  'Economy': 5,
#  'Topic': 1,
#  'Regain': 1,
#  'Footing': 1,
#  'AUTOS': 1,
#  'Dinosaur': 1,
#  'Hunter': 4,
#  '3/8/14': 1,
#  'Rob': 66,
#  'Portman': 11,
#  'R-OH': 1,
#  'delivers': 6,
#  'Address': 6,
#  'jobs': 2,
#  'Forget': 8,
#  'Kiev': 1,
#  'Real': 170,
#  'Fight': 43,
#  'Will': 284,
#  'Crimea': 1,
#  'Public': 47,
#  'financial': 2,
#  'disclosure': 1,
#  'report': 12,
#  'Nashville': 8,
#  'H1N1': 1,
#  'vaccinations': 1,
#  'offered': 3,
#  'Guantanamo': 1,
#  'Bay': 4,
#  'detainees': 1,
#  'Inquiry': 1,
#  'Sought': 1,
#  'Use': 19,
#  'CNN': 8,
#  'Don': 29,
#  'Lemon': 2,
#  "O'Reilly": 4,
#  'Criticism': 5,
#  'Of': 248,
#  'Black': 100,
#  'Community': 9,
#  'Far': 29,
#  'Enough': 17,
#  '2010': 4,
#  'Give': 39,
#  'Me': 87,
#  'Break': 61,
#  'Americans': 10,
#  'Food': 10,
#  '2011': 12,
#  'H.R.2122': 1,
#  '106th': 1,
#  '1999-2000': 1,
#  'Mandatory': 2,
#  'Background': 2,
#  'Check': 28,
#  'Noted': 1,
#  'Quoted': 1,
#  'Associated': 2,
#  'Hits': 24,
#  'NAFTA': 1,
#  'Support': 37,
#  'Bernie': 4,
#  'really': 18,
#  'socialist': 1,
#  'Eisenhower': 1,
#  'Madeleine': 5,
#  'Albright': 2,
#  'Lindsey': 13,
#  'Graham': 29,
#  'Kent': 17,
#  'Conrad': 31,
#  'Cote': 1,
#  'Oct.': 2,
#  '11': 44,
#  'Levin': 1,
#  'McCaffrey': 1,
#  'Myers': 5,
#  'roundtable': 1,
#  'Foreign': 3,
#  'Military': 5,
#  'Aid': 3,
#  'Major': 28,
#  'Recipient': 2,
#  'Country': 20,
#  'proposed': 5,
#  'Lynne': 3,
#  'Bernabei': 1,
#  'consultant': 1,
#  'promised': 2,
#  'halve': 1,
#  'federal': 2,
#  ...}

# %%
import operator
sorted_true = np.array(sorted(true_title_counter.items(), reverse=True, key=operator.itemgetter(1)))

# %%
sorted_true
# Out:
# array([[':', '3656'],
#        ["'", '3601'],
#        ['and', '3471'],
#        ...,
#        ['BIGGEST', '1'],
#        ['HXG', '1'],
#        ['butterflies', '1']], dtype='<U119')

# %%
sorted_false = np.array(sorted(fake_title_counter.items(), reverse=True, key=operator.itemgetter(1)))

# %%
sorted_false
# Out:
# array([['’', '1692'],
#        [':', '1115'],
#        [',', '1047'],
#        ...,
#        ['VOTING', '1'],
#        ['Boycott', '1'],
#        ['Mall', '1']], dtype='<U55')

# %%
print(sorted_true[:20])
print('\n', sorted_false[:20])
# Out:
# [[':' '3656']
#  ["'" '3601']
#  ['and' '3471']
#  ["'s" '3364']
#  ['’' '3265']
#  ['the' '3199']
#  ['to' '3018']
#  [',' '3011']
#  ['of' '2311']
#  ['in' '2097']
#  ['on' '1823']
#  ['The' '1821']
#  ['a' '1786']
#  ['for' '1465']
#  ['s' '1431']
#  ['‘' '1396']
#  ['Her' '1361']
#  ['Is' '1211']
#  ['at' '1167']
#  ['!' '977']]
#
#  [['’' '1692']
#  [':' '1115']
#  [',' '1047']
#  ['and' '1017']
#  ["'s" '757']
#  ['to' '752']
#  ['‘' '747']
#  ['s' '747']
#  ['?' '722']
#  ["'" '690']
#  ['To' '569']
#  ['Is' '557']
#  ['the' '522']
#  ['&' '490']
#  ['of' '478']
#  ['With' '478']
#  ['Jennifer' '478']
#  ['The' '470']
#  ['Kardashian' '466']
#  ['Brad' '412']]

# %%
fake_articles_amnt = len(gossipcop_fake['title']) + len(politifact_fake['title'])
true_articles_amnt = len(gossipcop_real['title']) + len(politifact_real['title'])

# %%
print(fake_articles_amnt)
print(true_articles_amnt)
# Out:
# 5755
# 17441

# %%
true_percent = sorted_true[:, 1].astype(int) / true_articles_amnt
fake_percent = sorted_false[:, 1].astype(int) / fake_articles_amnt

# %%
print(true_percent[:20])
print('\n', fake_percent[:20])
# Out:
# [0.20962101 0.20646752 0.19901382 0.19287885 0.18720257 0.18341838
#  0.17304054 0.17263918 0.13250387 0.12023393 0.10452382 0.10440915
#  0.10240239 0.08399748 0.08204805 0.08004128 0.07803452 0.06943409
#  0.0669113  0.05601743]
#
#  [0.29400521 0.19374457 0.18192876 0.1767159  0.13153779 0.13066898
#  0.12980017 0.12980017 0.12545613 0.11989574 0.09887055 0.0967854
#  0.09070374 0.08514335 0.08305821 0.08305821 0.08305821 0.08166811
#  0.08097307 0.07158992]

# %%
print("amount of ?'s in real article titles", true_title_counter["?"])
print("amount of ?'s in fake article titles", fake_title_counter["?"])
# Out:
# amount of ?'s in real article titles 705
# amount of ?'s in fake article titles 722

# %%
print("amount of ?'s in real article titles", true_title_counter["?"])
print("amount of ?'s in fake article titles", fake_title_counter["?"])
print(true_title_counter["?"] / true_articles_amnt)
print(fake_title_counter["?"] / fake_articles_amnt)
# Out:
# amount of ?'s in real article titles 705
# amount of ?'s in fake article titles 722
# 0.040421994151711486
# 0.1254561251086012

# %%
print("amount of !'s in real article titles", true_title_counter["!"])
print("amount of !'s in fake article titles", fake_title_counter["!"])
print(true_title_counter["!"] / true_articles_amnt)
print(fake_title_counter["!"] / fake_articles_amnt)
# Out:
# amount of !'s in real article titles 977
# amount of !'s in fake article titles 409
# 0.05601743019322287
# 0.07106863596872284

# %%
#print(sorted_true[:20])
#print('\n', sorted_false[:20])
for i in range(40):
    print(sorted_true[i], true_percent[i], '\t', sorted_false[i], fake_percent[i])
# Out:
# [':' '3656'] 0.20962100796972652 	 ['’' '1692'] 0.294005212858384
# ["'" '3601'] 0.20646751906427382 	 [':' '1115'] 0.19374456993918332
# ['and' '3471'] 0.19901381801502208 	 [',' '1047'] 0.18192875760208516
# ["'s" '3364'] 0.1928788486898687 	 ['and' '1017'] 0.17671589921807124
# ['’' '3265'] 0.1872025686600539 	 ["'s" '757'] 0.1315377932232841
# ['the' '3199'] 0.18341838197351068 	 ['to' '752'] 0.1306689834926151
# ['to' '3018'] 0.17304053666647554 	 ['‘' '747'] 0.12980017376194614
# [',' '3011'] 0.1726391835330543 	 ['s' '747'] 0.12980017376194614
# ['of' '2311'] 0.1325038701909294 	 ['?' '722'] 0.1254561251086012
# ['in' '2097'] 0.12023393154062267 	 ["'" '690'] 0.11989574283231973
# ['on' '1823'] 0.10452382317527664 	 ['To' '569'] 0.09887054735013032
# ['The' '1821'] 0.104409150851442 	 ['Is' '557'] 0.09678540399652476
# ['a' '1786'] 0.10240238518433577 	 ['the' '522'] 0.09070373588184187
# ['for' '1465'] 0.08399747720887564 	 ['&' '490'] 0.08514335360556038
# ['s' '1431'] 0.08204804770368672 	 ['of' '478'] 0.08305821025195483
# ['‘' '1396'] 0.08004128203658047 	 ['With' '478'] 0.08305821025195483
# ['Her' '1361'] 0.07803451636947423 	 ['Jennifer' '478'] 0.08305821025195483
# ['Is' '1211'] 0.06943409208187604 	 ['The' '470'] 0.08166811468288444
# ['at' '1167'] 0.06691130095751391 	 ['Kardashian' '466'] 0.08097306689834927
# ['!' '977'] 0.05601743019322287 	 ['Brad' '412'] 0.07158992180712424
# ['With' '911'] 0.05223324350667966 	 ['!' '409'] 0.07106863596872284
# ['with' '902'] 0.05171721804942377 	 ['a' '402'] 0.06985230234578628
# ['&' '855'] 0.04902241843930967 	 ['Jenner' '382'] 0.06637706342311034
# ['?' '705'] 0.040421994151711486 	 ['Pitt' '380'] 0.06602953953084274
# ['2018' '701'] 0.0401926495040422 	 ['in' '356'] 0.061859252823631625
# ['Kardashian' '692'] 0.03967662404678631 	 ['Justin' '350'] 0.060816681146828845
# ['After' '687'] 0.0393899432371997 	 ['on' '348'] 0.06046915725456125
# ['New' '640'] 0.036695143627085605 	 ['Her' '324'] 0.05629887054735013
# ["''" '609'] 0.034917722607648645 	 ['for' '298'] 0.05178105994787142
# ['``' '597'] 0.03422968866464079 	 ['Kim' '291'] 0.05056472632493484
# ['How' '581'] 0.033312310073963645 	 ['Angelina' '290'] 0.05039096437880104
# ['Awards' '571'] 0.03273894845479044 	 ['Jolie' '285'] 0.04952215464813206
# ['About' '534'] 0.03061751046384955 	 ['A' '283'] 0.049174630755864465
# ['I' '526'] 0.03015882116851098 	 ['In' '280'] 0.04865334491746308
# ['A' '506'] 0.029012097930164554 	 ['Aniston' '280'] 0.04865334491746308
# ['She' '501'] 0.02872541712057795 	 ['with' '277'] 0.048132059079061686
# ['His' '499'] 0.028610744796743307 	 ['After' '268'] 0.04656820156385751
# ['Season' '484'] 0.027750702367983486 	 ['For' '260'] 0.045178105994787145
# ['her' '484'] 0.027750702367983486 	 ['Selena' '241'] 0.041876629018245
# ['is' '473'] 0.027120004586892954 	 ['On' '235'] 0.04083405734144222

# %%
print("amount of !'s in real article titles", true_title_counter["To"])
print("amount of !'s in fake article titles", fake_title_counter["To"])
print(true_title_counter["To"] / true_articles_amnt)
print(fake_title_counter["To"] / fake_articles_amnt)
# Out:
# amount of !'s in real article titles 389
# amount of !'s in fake article titles 569
# 0.02230376698583797
# 0.09887054735013032
